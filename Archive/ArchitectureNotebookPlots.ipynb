# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)
three_df = pd.read_csv('ThreeSubjectheadings.csv')
one_df = pd.read_csv('OneSubjectHeading.csv')

# %%
three_df.head()
# Out:
#           Item Loan Id Loan Date In House Loan Indicator          Barcode  \
# 0  2252958767220001701  1/2/2018                       N  31951D01848189P
# 1  2252958767220001701  1/2/2018                       N  31951D01848189P
# 2  2252958767220001701  1/2/2018                       N  31951D01848189P
# 3  2252959196040001701  1/2/2018                       N  31951000140967E
# 4  2252959196040001701  1/2/2018                       N  31951000140967E
#
#   Permanent Call Number Circulation Library Code Owning Library Code  \
# 0       HT119 .S65 2000                    TARCH               TARCH
# 1       HT119 .S65 2000                    TARCH               TARCH
# 2       HT119 .S65 2000                    TARCH               TARCH
# 3             E159 .H77                    TARCH               TARCH
# 4             E159 .H77                    TARCH               TARCH
#
#                                     Title (Complete)  \
# ...

# %%
# rename columns
one_df = one_df.rename(columns={'Title (Complete)' : 'Title',
                   'Permanent Call Number' : 'Call Number',
               'Loan Date' : 'Date'})

#convert to string and change year to whole year
one_df['Date'] = one_df['Date'].astype(str).str[-4:]
one_df.head(5)
# Out:
#           Item Loan Id  Date In House Loan Indicator          Barcode  \
# 0  2252958767220001701  2018                       N  31951D01848189P
# 1  2252959196040001701  2018                       N  31951000140967E
# 2  2252965815260001701  2018                       N  31951P012191854
# 3  2252965816190001701  2018                       N  31951P012191862
# 4  2252965817370001701  2018                       N  31951P012055993
#
#        Call Number Circulation Library Code Owning Library Code  \
# 0  HT119 .S65 2000                    TARCH               TARCH
# 1        E159 .H77                    TARCH               TARCH
# 2          Unknown                    TARCH               TARCH
# 3          Unknown                    TARCH               TARCH
# 4          Unknown                    TARCH               TARCH
#
#                                                Title  \
# 0  Postmetropolis : critical studies of cities an...
# ...

# %%
# rename columns
three_df = three_df.rename(columns={'Title (Complete)' : 'Title',
                   'Permanent Call Number' : 'Call Number',
               'Loan Date' : 'Date'})

#convert to string and change year to whole year
three_df['Date'] = three_df['Date'].astype(str).str[-4:]
three_df.head(5)
# Out:
#           Item Loan Id  Date In House Loan Indicator          Barcode  \
# 0  2252958767220001701  2018                       N  31951D01848189P
# 1  2252958767220001701  2018                       N  31951D01848189P
# 2  2252958767220001701  2018                       N  31951D01848189P
# 3  2252959196040001701  2018                       N  31951000140967E
# 4  2252959196040001701  2018                       N  31951000140967E
#
#        Call Number Circulation Library Code Owning Library Code  \
# 0  HT119 .S65 2000                    TARCH               TARCH
# 1  HT119 .S65 2000                    TARCH               TARCH
# 2  HT119 .S65 2000                    TARCH               TARCH
# 3        E159 .H77                    TARCH               TARCH
# 4        E159 .H77                    TARCH               TARCH
#
#                                                Title  \
# 0  Postmetropolis : critical studies of cities an...
# ...

# %%
# Create a mask to subset data by year
def Mask(year, df):
    mask_year = df[(df.Date == year)]
    #mask_year.to_csv('FirstThree' + 'AlmaData' + str(year) +'.csv', index=False )
    # print(mask_year)
    return(mask_year)

# %% [markdown]
# for i in range(2018,2024):
#     files = Mask(str(i), three_df)
#     uniques = (i, len(files['Subjects'].unique()))
#     print(uniques)

# %%
three_df_counts = three_df['Date'].value_counts().reset_index(name='Counts').sort_values(by=['Counts'], ascending=[False])
allcheckouts = three_df_counts['Counts'].sum()
three_df_counts['Total Counts %'] = three_df_counts['Counts'] / allcheckouts
three_df_counts
# Out:
#    Date  Counts  Total Counts %
# 0  2018   14397        0.282427
# 1  2019   13488        0.264595
# 2  2022    6526        0.128021
# 3  2023    6411        0.125765
# 4  2021    5200        0.102009
# 5  2020    4954        0.097183

# %%
three_subject_counts = three_df['Subjects'].value_counts()
three_subject_counts.head(25)
# Out:
# Subjects
# Architecture--Periodicals                                1061
# Architecture, Modern--20th century                        789
# Architecture--Spain--Periodicals.                         569
# Architecture--Espagne--20e siècle--Périodiques.         566
# Architecture                                              435
# Architecture, Modern--21st century                        403
# City planning                                             374
# Architectural design                                      302
# Architecture and society                                  276
# Architecture--Philosophy                                  267
# Landscape architecture                                    246
# Architecture--Environmental aspects                       229
# Sustainable architecture                                  208
# Architecture--Human factors                               208
# Building--Periodicals                                     206
# ...

# %%
one_subject_counts = one_df['Subjects'].value_counts()
one_subject_counts.head(25)
# Out:
# Subjects
# Architecture--Spain--Periodicals.                          569
# Architecture--Periodicals                                  432
# Architecture, Modern--20th century                         253
# City planning                                              177
# Architecture                                               136
# Architecture and society                                   128
# Architectural design                                       125
# Architecture--Philosophy                                   120
# Architecture--Environmental aspects                        119
# Landscape architecture                                     114
# Andō, Tadao,--1941-                                        110
# Architecture, Domestic--Designs and plans                  101
# Building, Wooden                                            78
# Architecture--Human factors                                 77
# Sustainable architecture                                    73
# ...

# %%
# Create a bar plot of top 25 subject headings for the first three subjects DataFrame

three_subject_counts.head(25).plot.barh()
# Out:
# <Axes: ylabel='Subjects'>

# %%
# Create a bar plot of top 25 subject headings for the first subject DataFrame

one_subject_counts.head(25).plot.barh()
# Out:
# <Axes: ylabel='Subjects'>

# %%
# Create DataFrames from Series
df1 = pd.DataFrame(three_subject_counts).reset_index()
df2 = pd.DataFrame(one_subject_counts).reset_index()

# Merge SeriDataFrames into one DataFrame
bar_df = pd.merge(df1, df2, how='left', on='Subjects')
bar_df = bar_df.rename(columns={'count_x': 'Three Subjects', 'count_y': 'First Subjects'})
bar_df.head(25)
# Out:
#                                              Subjects  Three Subjects  \
# 0                           Architecture--Periodicals            1061
# 1                  Architecture, Modern--20th century             789
# 2                   Architecture--Spain--Periodicals.             569
# 3   Architecture--Espagne--20e siècle--Périodiques.             566
# 4                                        Architecture             435
# 5                  Architecture, Modern--21st century             403
# 6                                       City planning             374
# 7                                Architectural design             302
# 8                            Architecture and society             276
# 9                            Architecture--Philosophy             267
# 10                             Landscape architecture             246
# 11                Architecture--Environmental aspects             229
# ...

# %%
# Create double bar graph of both different subject headings

bar_df = bar_df.head(30)
bar_df.plot(x='Subjects', y=['First Subjects', 'Three Subjects'], kind='barh')
# Out:
# <Axes: ylabel='Subjects'>

# %%
one_df.groupby('Subjects').size().sort_values(ascending=[False]).head(25)
# Out:
# Subjects
# Architecture--Spain--Periodicals.                          569
# Architecture--Periodicals                                  432
# Architecture, Modern--20th century                         253
# City planning                                              177
# Architecture                                               136
# Architecture and society                                   128
# Architectural design                                       125
# Architecture--Philosophy                                   120
# Architecture--Environmental aspects                        119
# Landscape architecture                                     114
# Andō, Tadao,--1941-                                        110
# Architecture, Domestic--Designs and plans                  101
# Building, Wooden                                            78
# Architecture--Human factors                                 77
# Sustainable architecture                                    73
# ...

# %%
three_df.groupby('Subjects').size().sort_values(ascending=[False]).head(25)
# Out:
# Subjects
# Architecture--Periodicals                                1061
# Architecture, Modern--20th century                        789
# Architecture--Spain--Periodicals.                         569
# Architecture--Espagne--20e siècle--Périodiques.         566
# Architecture                                              435
# Architecture, Modern--21st century                        403
# City planning                                             374
# Architectural design                                      302
# Architecture and society                                  276
# Architecture--Philosophy                                  267
# Landscape architecture                                    246
# Architecture--Environmental aspects                       229
# Architecture--Human factors                               208
# Sustainable architecture                                  208
# Building--Periodicals                                     206
# ...

# %%
# Create a number of counts via group by author and date for the first subject DataFrame

AuthorCounts = one_df.groupby(['Author', 'Date']).size().reset_index(name='Counts').sort_values(by=['Counts'], ascending=[False])
AuthorCounts.reset_index(drop = True).head(25)
# Out:
#                                 Author  Date  Counts
# 0                  Ando?, Tadao, 1941-  2018      33
# 1                  Ando?, Tadao, 1941-  2021      25
# 2            Breuer, Marcel, 1902-1981  2019      23
# 3                         Holl, Steven  2019      21
# 4              Le Corbusier, 1887-1965  2018      21
# 5          Ching, Francis D. K., 1943-  2018      20
# 6                  Ando?, Tadao, 1941-  2019      20
# 7                  Ando?, Tadao, 1941-  2023      19
# 8                Koolhaas, Rem author.  2018      18
# 9                    Frampton, Kenneth  2018      17
# 10  Olmsted, Frederick Law, 1822-1903.  2019      16
# 11           Breuer, Marcel, 1902-1981  2018      15
# 12                   Wittkower, Rudolf  2019      15
# 13                     Vidler, Anthony  2018      15
# 14                       LaVine, Lance  2021      15
# 15                        Holl, Steven  2018      15
# 16                   Etlin, Richard A.  2018      14
# ...

# %%
# Create a number of counts via group by author and date for the first three subjects DataFrame

ThreeAuthorCounts = three_df.groupby(['Author', 'Date']).size().reset_index(name='Counts').sort_values(by=['Counts'], ascending=[False])
ThreeAuthorCounts.reset_index(drop = True).head(25)
# Out:
#                                          Author  Date  Counts
# 0                           Andō, Tadao, 1941-  2018     104
# 1                                 Brown, Jackum  2022      87
# 2                             Frampton, Kenneth  2019      80
# 3            Olmsted, Frederick Law, 1822-1903.  2019      78
# 4                           Andō, Tadao, 1941-  2021      77
# 5                                 Minke, Gernot  2021      76
# 6                               Jodidio, Philip  2023      74
# 7                             Etlin, Richard A.  2018      68
# 8                   Ching, Francis D. K., 1943-  2018      67
# 9                                 Koolhaas, Rem  2019      65
# 10                            Frampton, Kenneth  2018      63
# 11                      Le Corbusier, 1887-1965  2018      62
# 12                          Andō, Tadao, 1941-  2019      62
# 13                                 Holl, Steven  2019      60
# ...

# %%
def DiffPerc(df, sort_year, order):
    # use mask function to subset by year
    subset_2018 = Mask('2018', df)
    subset_2019 = Mask('2019', df)
    subset_2020 = Mask('2020', df)
    subset_2021 = Mask('2021', df)
    subset_2022 = Mask('2022', df)
    subset_2023 = Mask('2023', df)
    
    # group by counts for every year

    
    counts_2018 = subset_2018.groupby(['Subjects', 'Date']).size().reset_index(name='Counts').sort_values(by=['Counts'], ascending=[False])
    counts_2019 = subset_2019.groupby(['Subjects', 'Date']).size().reset_index(name='Counts').sort_values(by=['Counts'], ascending=[False])
    counts_2020 = subset_2020.groupby(['Subjects', 'Date']).size().reset_index(name='Counts').sort_values(by=['Counts'], ascending=[False])
    counts_2021 = subset_2021.groupby(['Subjects', 'Date']).size().reset_index(name='Counts').sort_values(by=['Counts'], ascending=[False])
    counts_2022 = subset_2022.groupby(['Subjects', 'Date']).size().reset_index(name='Counts').sort_values(by=['Counts'], ascending=[False])
    counts_2023 = subset_2023.groupby(['Subjects', 'Date']).size().reset_index(name='Counts').sort_values(by=['Counts'], ascending=[False])
    
     # create total checkouts variable for every year
    checkouts2018 = counts_2018['Counts'].sum()

    checkouts2019 = counts_2019['Counts'].sum()

    checkouts2020 = counts_2020['Counts'].sum()

    checkouts2021 = counts_2021['Counts'].sum()

    checkouts2022 = counts_2022['Counts'].sum()

    checkouts2023 = counts_2023['Counts'].sum()

 
    # create counts variable for every year

    counts_2018['Subj %'] = counts_2018['Counts'] / checkouts2018

    counts_2019['Subj %'] = counts_2019['Counts'] / checkouts2019
 
    counts_2020['Subj %'] = counts_2020['Counts'] / checkouts2020
 
    counts_2021['Subj %'] = counts_2021['Counts'] / checkouts2021
 
    counts_2022['Subj %'] = counts_2022['Counts'] / checkouts2022
 
    counts_2023['Subj %'] = counts_2023['Counts'] / checkouts2023
    
    merged_df = pd.merge(counts_2018, counts_2019, how='left', on='Subjects')

    merged_df = merged_df.rename(columns={'Date_x' : 'Date 2018',
                    'Counts_x' : 'Counts 2018',
                'Subj %_x' : 'Subj % 2018',
                'Date_y' : 'Date 2019',
                    'Counts_y' : 'Counts 2019',
                'Subj %_y' : 'Subj % 2019'})
    
    merged_df2 = pd.merge(merged_df, counts_2020, how='left', on='Subjects')
    merged_df2 = merged_df2.rename(columns={'Date' : 'Date 2020',
                    'Counts' : 'Counts 2020',
                'Subj %' : 'Subj % 2020'})
    
    merged_df3 = pd.merge(merged_df2, counts_2021, how='left', on='Subjects')
    merged_df3 = merged_df3.rename(columns={'Date' : 'Date 2021',
                    'Counts' : 'Counts 2021',
                'Subj %' : 'Subj % 2021'})
    
    merged_df4 = pd.merge(merged_df3, counts_2022, how='left', on='Subjects')
    merged_df4 = merged_df4.rename(columns={'Date' : 'Date 2022',
                    'Counts' : 'Counts 2022',
                'Subj %' : 'Subj % 2022'})
    
    merged_df5 = pd.merge(merged_df4, counts_2023, how='left', on='Subjects')
    merged_df5 = merged_df5.rename(columns={'Date' : 'Date 2023',
                    'Counts' : 'Counts 2023',
                'Subj %' : 'Subj % 2023'})
    
    # subset df
    merged_df5 =merged_df5[['Subjects', 'Subj % 2018', 'Subj % 2019', 'Subj % 2020', 'Subj % 2021', 'Subj % 2022', 'Subj % 2023']]

    # create new column by substracting % of 2023 - 2018
    merged_df5['2023 Diff 2018'] = merged_df5['Subj % 2023'] - merged_df5['Subj % 2018']
    
    merged_df5['2023 Diff 2020'] = merged_df5['Subj % 2023'] - merged_df5['Subj % 2020']


    merged_df5['2022 Diff 2018'] = merged_df5['Subj % 2022'] - merged_df5['Subj % 2018']

    merged_df5['2021 Diff 2018'] = merged_df5['Subj % 2021'] - merged_df5['Subj % 2018']

    merged_df5['2020 Diff 2018'] = merged_df5['Subj % 2020'] - merged_df5['Subj % 2018']

    merged_df5['2019 Diff 2018'] = merged_df5['Subj % 2019'] - merged_df5['Subj % 2018']

    #merged_df5 = merged_df5.head(head).sort_values(by=['Subj % 2023'], ascending=[order]).reset_index(drop=True)
    merged_df5 = merged_df5.sort_values(by=[sort_year], ascending=[order]).reset_index(drop=True)

    merged_df5 = merged_df5[['Subjects', 'Subj % 2018', 'Subj % 2019', 'Subj % 2020', 'Subj % 2021', 'Subj % 2022', 'Subj % 2023', 
                             '2019 Diff 2018', '2020 Diff 2018','2021 Diff 2018', '2022 Diff 2018',  '2023 Diff 2018', '2023 Diff 2020']]

  
    return merged_df5

# %%
# sorted  by 2023 Diff 2018 on all there subjects (largest to smallest change)
diff_three_df2023 = DiffPerc(three_df, '2023 Diff 2018', False)
diff_three_df2023.head(15)
# Out:
#                                              Subjects  Subj % 2018  \
# 0   Architecture--Espagne--20e siècle--Périodiques.     0.007502
# 1                   Architecture--Spain--Periodicals.     0.007571
# 2           Architecture, Domestic--Designs and plans     0.001875
# 3                            Architecture domestique.     0.000208
# 4   Architecture, Modern--20th century--Designs an...     0.002501
# 5                 Architecture--Environmental aspects     0.004168
# 6          Architecture--Japan--History--20th century     0.002848
# 7                         Architecture--Human factors     0.003542
# 8                            Sustainable architecture     0.003751
# 9                                        Architecture     0.008821
# 10                             Architecture, Domestic     0.003056
# 11                             Landscape architecture     0.004306
# 12                                   Building, Wooden     0.001250
# ...

# %%
# sorted  by 2020 Diff 2018 on all there subjects (largest to smallest change)
diff_three_df2020 = DiffPerc(three_df, '2020 Diff 2018', False)
diff_three_df2020.head(15)
# Out:
#                                        Subjects  Subj % 2018  Subj % 2019  \
# 0           Architecture--Environmental aspects     0.004168     0.004226
# 1                                 City planning     0.008127     0.006005
# 2                 Architecture, Domestic--Japan     0.001042     0.001038
# 3                   Architecture--Human factors     0.003542     0.003633
# 4                      Sustainable architecture     0.003751     0.003929
# 5            Architecture, Baroque--Italy--Rome     0.000278     0.000148
# 6   Architecture--Japan--History--21st century.     0.000695     0.000593
# 7             Alexander--VII,--Pope,--1599-1667     0.000139     0.000074
# 8       Architecture and society--United States     0.000834     0.001186
# 9                       ARCHITECTURE / General.     0.001250     0.001557
# 10   Architecture--Japan--History--20th century     0.002848     0.002521
# 11                Sustainable urban development     0.000347     0.000519
# ...

# %%
# sorted  by 2023 Diff 2018 on first three subjects decreasing (smallest to biggest)

diff_three_df2023_dec = DiffPerc(three_df, '2023 Diff 2018', True)
diff_three_df2023_dec.head(15)
# Out:
#                                              Subjects  Subj % 2018  \
# 0                                       City planning     0.008127
# 1                                         Periodicals     0.003056
# 2                  Architecture, Modern--20th century     0.015628
# 3                            Architecture--Philosophy     0.006876
# 4     Architecture, Modern--20th century--Exhibitions     0.002014
# 5   Architecture--United States--History--20th cen...     0.004654
# 6     Architecture, Modern--20th century--Periodicals     0.001528
# 7                          Breuer, Marcel,--1902-1981     0.001598
# 8                               Building--Periodicals     0.003751
# 9                          City planning--Periodicals     0.002014
# 10                         Kahn, Louis I.,--1901-1974     0.001528
# 11                           Le Corbusier,--1887-1965     0.001667
# 12                           Architecture, Postmodern     0.001459
# ...

# %%
# sorted  by 2020 Diff 2018 on only first subject decreasing (smallest to biggest)

diff_three_df2020_dec = DiffPerc(three_df, '2020 Diff 2018', True)
diff_three_df2020_dec.head(15)
# Out:
#                                              Subjects  Subj % 2018  \
# 0                           Architecture--Periodicals     0.019310
# 1                                        Architecture     0.008821
# 2                               Building--Periodicals     0.003751
# 3   Architecture--Espagne--20e siècle--Périodiques.     0.007502
# 4                   Architecture--Spain--Periodicals.     0.007571
# 5                                         Periodicals     0.003056
# 6   Architecture--United States--History--20th cen...     0.004654
# 7                            Architecture--Philosophy     0.006876
# 8                                Andō, Tadao,--1941-     0.002778
# 9     Architecture, Modern--21st century--Exhibitions     0.001598
# 10                               Architecture, Modern     0.002917
# 11                           Le Corbusier,--1887-1965     0.001667
# 12                   Architectural drawing--Technique     0.001459
# ...

# %%
# sorted  by 2023 Diff 2018 on only first subject (largest to smallest change)
diff_one_df2023 = DiffPerc(one_df, '2023 Diff 2018', False)
diff_one_df2023.head(15)
# Out:
#                                        Subjects  Subj % 2018  Subj % 2019  \
# 0             Architecture--Spain--Periodicals.     0.018528     0.029105
# 1     Architecture, Domestic--Designs and plans     0.002380     0.005308
# 2           Architecture--Environmental aspects     0.003910     0.005491
# 3                        Landscape architecture     0.003740     0.005858
# 4                              Building, Wooden     0.002720     0.004210
# 5                           Architecture--Japan     0.000510     0.000732
# 6                      Architecture and climate     0.001530     0.002380
# 7                        Architecture, Domestic     0.002380     0.002014
# 8    Architecture--Japan--History--20th century     0.001360     0.002014
# 9                         Light in architecture     0.001530     0.000549
# 10  Architecture, Domestic--Spain--Periodicals.     0.000170     0.000549
# 11                                      Facades     0.000680     0.000366
# ...

# %%
# sorted  by 2020 Diff 2018 on only first subject (largest to smallest change)
diff_one_df2020 = DiffPerc(one_df, '2020 Diff 2018', False)
diff_one_df2020.head(15)
# Out:
#                                              Subjects  Subj % 2018  \
# 0                 Architecture--Environmental aspects     0.003910
# 1                       Architecture, Domestic--Japan     0.002380
# 2                                       City planning     0.010199
# 3                   Alexander--VII,--Pope,--1599-1667     0.000340
# 4          Architecture--Japan--History--20th century     0.001360
# 5                  Architecture, Modern--20th century     0.011899
# 6   Bernini, Gian Lorenzo,--1598-1680--Criticism a...     0.000340
# 7                            Architecture and biology     0.000850
# 8                City planning--Environmental aspects     0.001870
# 9                 Architecture, Domestic--Periodicals     0.000170
# 10                  Bernini, Gian Lorenzo,--1598-1680     0.000510
# 11                   Borromini, Francesco,--1599-1667     0.000510
# 12                           Architecture and society     0.006119
# ...

# %%
# sorted  by 2023 Diff 2018 on only first subject decreasing (smallest to biggest)

diff_one_df2023_dec = DiffPerc(one_df, '2023 Diff 2018', True)
diff_one_df2023_dec.head(15)
# Out:
#                                              Subjects  Subj % 2018  \
# 0                           Architecture--Periodicals     0.023457
# 1                  Architecture, Modern--20th century     0.011899
# 2                          Breuer, Marcel,--1902-1981     0.003910
# 3                          Kahn, Louis I.,--1901-1974     0.003740
# 4                                       City planning     0.010199
# 5                               Architecture--History     0.004080
# 6                                            Building     0.002890
# 7                    Architectural drawing--Technique     0.003570
# 8                            Le Corbusier,--1887-1965     0.002720
# 9                            Architecture--Philosophy     0.007139
# 10  Le Corbusier,--1887-1965--Criticism and interp...     0.003910
# 11    Architecture, Modern--21st century--Exhibitions     0.002550
# 12                        Architecture--Italy--Venice     0.002040
# ...

# %%
# sorted  by 2020 Diff 2018 on only first subject decreasing (smallest to biggest)

diff_one_df2020_dec = DiffPerc(one_df, '2020 Diff 2018', True)
diff_one_df2020_dec.head(15)
# Out:
#                                              Subjects  Subj % 2018  \
# 0                           Architecture--Periodicals     0.023457
# 1                   Architecture--Spain--Periodicals.     0.018528
# 2                                 Andō, Tadao,--1941-     0.005779
# 3                                        Architecture     0.007649
# 4                    Architectural drawing--Technique     0.003570
# 5                          Kahn, Louis I.,--1901-1974     0.003740
# 6                          Breuer, Marcel,--1902-1981     0.003910
# 7                                  Glass construction     0.002380
# 8                            Le Corbusier,--1887-1965     0.002720
# 9                                    Building, Wooden     0.002720
# 10  Le Corbusier,--1887-1965--Criticism and interp...     0.003910
# 11                        Architecture and technology     0.003400
# 12                                           Building     0.002890
# ...

# %%
# plot 2023 diff 2018
ax = diff_three_df2023.head(15).sort_values('2023 Diff 2018', ascending=True).plot(x="Subjects", y='2023 Diff 2018', kind="barh") 
ax
# Out:
# <Axes: ylabel='Subjects'>

# %% [markdown]
# diff_all_plots = diff_df2023.head(15).sort_values('2023 Diff 2018', ascending=True).plot(x="Subjects", y=['Subj % 2019', '2023 Diff 2018', '2022 Diff 2018', '2021 Diff 2018', '2020 Diff 2018', '2019 Diff 2018'], kind="barh")
# diff_all_plots

# %% [markdown]
# diff_all_plots = diff_three_df2023.head(15).sort_values('2023 Diff 2018', ascending=True).plot(x="Subjects", y=['Subj % 2018', 'Subj % 2019', '2023 Diff 2018', '2022 Diff 2018', '2021 Diff 2018', '2020 Diff 2018', '2019 Diff 2018'], kind="barh")
# diff_all_plots

# %% [markdown]
# ax = diff_df2023.head(15).plot(x="Subjects", y='Subj % 2019', kind="barh", color="blue")
# #ax
# diff_all_plots = diff_df2023.head(15).sort_values('2023 Diff 2018', ascending=True).plot(x="Subjects", y=['2023 Diff 2018', '2022 Diff 2018', '2021 Diff 2018', '2020 Diff 2018', '2019 Diff 2018'], kind="barh", ax=ax, color=["maroon", "orange", "green", "purple", "black"])
# diff_all_plots

# %% [markdown]
# ax = diff_three_df2023.head(15).plot(x="Subjects", y='Subj % 2019', kind="barh", color="blue")
#
# diff_all_plots = diff_three_df2023.head(15).sort_values('2023 Diff 2018', ascending=True).plot(x="Subjects", y=['2023 Diff 2018', '2022 Diff 2018', '2021 Diff 2018', '2020 Diff 2018', '2019 Diff 2018'], kind="barh", ax=ax, color=["maroon", "orange", "green", "purple", "black"])
# diff_all_plots

# %% [markdown]
# diff2023_plot = diff_df2023.head(15).sort_values('2023 Diff 2018', ascending=True).plot(x="Subjects", y=['Subj % 2019', '2023 Diff 2018', '2020 Diff 2018'], kind="barh")
# diff2023_plot

# %% [markdown]
# diff2023_plot = diff_three_df2023.head(15).sort_values('2023 Diff 2018', ascending=True).plot(x="Subjects", y=['Subj % 2019', '2023 Diff 2018', '2020 Diff 2018'], kind="barh")
# diff2023_plot

# %%
# plotting sorted  by 2023 Diff 2018 on all there subjects (largest to smallest change)
ThreeSHGrowth2018 = diff_three_df2023.rename(columns={"2023 Diff 2018": "2023 Growth %"})
ThreeSHGrowth2018 = ThreeSHGrowth2018.sort_values('2023 Growth %', ascending=False)
ThreeSHGrowth2018 = ThreeSHGrowth2018.head(20).sort_values('2023 Growth %', ascending=True).plot(x="Subjects", y=['Subj % 2018', 'Subj % 2023', '2023 Growth %'], kind="barh") 
ThreeSHGrowth2018.set_title('Subject Headings Growth From 2018 to 2023')

ThreeSHGrowth2018
# Out:
# <Axes: title={'center': 'Subject Heading Growth From 2018 to 2023'}, ylabel='Subjects'>

# %%
# plotting sorted  by 2023 Diff 2018 on all there subjects (largest to smallest change)
ThreeSHGrowth2020 = diff_three_df2023.rename(columns={"2023 Diff 2020": "2023 Growth %"})
ThreeSHGrowth2020 = ThreeSHGrowth2020.sort_values('2023 Growth %', ascending=False)
ThreeSHGrowth2020 = ThreeSHGrowth2020.head(20).sort_values('2023 Growth %', ascending=True).plot(x="Subjects", y=['Subj % 2020', 'Subj % 2023', '2023 Growth %'], kind="barh") 
ThreeSHGrowth2020.set_title('Subject Headings Growth From 2020 to 2023')

ThreeSHGrowth2020
# Out:
# <Axes: title={'center': 'Subject Heading Growth From 2020 to 2023'}, ylabel='Subjects'>

# %%
# plotting sorted  by 2023 Diff 2020 on all there subjects (declining change)
ThreeSHDec2020 = diff_three_df2023.rename(columns={"2023 Diff 2020": "2023 Decline %"})
ThreeSHDec2020 = ThreeSHDec2020.sort_values('2023 Decline %', ascending=True)
ThreeSHDec2020 = ThreeSHDec2020.head(20).sort_values('2023 Decline %', ascending=False).plot(x="Subjects", y=['Subj % 2020', 'Subj % 2023', '2023 Decline %'], kind="barh") 
ThreeSHDec2020.set_title('Subject Headings Decline From 2020 to 2023')

ThreeSHDec2020
# Out:
# <Axes: title={'center': 'Subject Headings Decline From 2020 to 2023'}, ylabel='Subjects'>

# %% [markdown]
# # plotting sorted  by 2020 Diff 2018 on all there subjects (largest to smallest change)
#
# three_plot2020 = diff_three_df2020.head(15).sort_values('2020 Diff 2018', ascending=True).plot(x="Subjects", y=['Subj % 2018', 'Subj % 2020', 'Subj % 2023', '2020 Diff 2018'], kind="barh")
# three_plot2020.set_title('Three Subject Heading Sorted By Largest 2020 Diff 2018')
#
# three_plot2020

# %% [markdown]
# # plotting sorted  by 2023 Diff 2018 on only first subject decreasing (smallest to biggest)
#
# three_plot2023_dec = diff_three_df2023_dec.head(15).sort_values('2023 Diff 2018', ascending=False).plot(x="Subjects", y=['Subj % 2018', 'Subj % 2020', 'Subj % 2023', '2023 Diff 2018'], kind="barh")
# three_plot2023_dec.set_title('Three Subject Heading Sorted By Smallest 2023 Diff 2018')
#
# three_plot2023_dec

# %% [markdown]
# # plotting sorted  by 2020 Diff 2018 on only first subject decreasing (smallest to biggest)
#
# three_plot2020_dec = diff_three_df2020_dec.head(15).sort_values('2020 Diff 2018', ascending=False).plot(x="Subjects", y=['Subj % 2018', 'Subj % 2020', 'Subj % 2023', '2020 Diff 2018'], kind="barh")
# three_plot2020_dec.set_title('Three Subject Heading Sorted By Smallest 2020 Diff 2018')
#
# three_plot2020_dec

# %% [markdown]
# # plotting sorted  by 2023 Diff 2018 on first subject (largest to smallest change)
#
# one_plot2023 = diff_one_df2023.head(15).sort_values('2023 Diff 2018', ascending=True).plot(x="Subjects", y=['Subj % 2018', 'Subj % 2020', 'Subj % 2023', '2023 Diff 2018'], kind="barh")
# one_plot2023.set_title('One Subject Heading Sorted By Largest 2023 Diff 2018')
#
# one_plot2023

# %% [markdown]
# # plotting sorted  by 2020 Diff 2018 on first subject (largest to smallest change)
#
# one_plot2020 = diff_one_df2020.head(15).sort_values('2020 Diff 2018', ascending=True).plot(x="Subjects", y=['Subj % 2018', 'Subj % 2020', 'Subj % 2023', '2020 Diff 2018'], kind="barh")
# one_plot2020.set_title('One Subject Heading Sorted By Largest 2020 Diff 2018')

# %%
one_plot2020

# %% [markdown]
# # plotting sorted  by 2023 Diff 2018 on only first subject decreasing (smallest to biggest)
#
# one_plot2023_dec = diff_one_df2023_dec.head(15).sort_values('2023 Diff 2018', ascending=False).plot(x="Subjects", y=['Subj % 2018', 'Subj % 2020', 'Subj % 2023', '2023 Diff 2018'], kind="barh")
# one_plot2023_dec.set_title('One Subject Heading Sorted By Smallest 2023 Diff 2018')
#
# one_plot2023_dec

# %% [markdown]
# # plotting sorted  by 2023 Diff 2018 on only first subject decreasing (smallest to biggest)
#
# one_plot2020_dec = diff_one_df2020_dec.head(15).sort_values('2020 Diff 2018', ascending=False).plot(x="Subjects", y=['Subj % 2018', 'Subj % 2020', 'Subj % 2023', '2020 Diff 2018'], kind="barh")
# one_plot2020_dec.set_title('One Subject Heading Sorted By Smallest 2020 Diff 2018')
# one_plot2020_dec

# %%
# Create DataFrames from Series
#df1 = pd.DataFrame(three_subject_counts).reset_index()
#df2 = pd.DataFrame(one_subject_counts).reset_index()

# Merge SeriDataFrames into one DataFrame
bar_df = pd.merge(df1, df2, how='left', on='Subjects')
bar_df = bar_df.rename(columns={'count_x': 'Three Subjects', 'count_y': 'First Subjects'})
bar_df.head(25)

bar_df = bar_df.head(30)
bar_df.plot(x='Subjects', y=['First Subjects', 'Three Subjects'], kind='barh')

# %% [markdown]
# three2023 = diff_three_df2023
# three2023 = three2023[['Subjects', 'Subj % 2023', 'Subj % 2020']]
# three2023 = three2023.reset_index(drop=True)
#
# one2023 = diff_one_df2023
# one2023 = one2023[['Subjects', 'Subj % 2023', 'Subj % 2020']]
# one2023 = one2023.reset_index(drop=True)
# #comp_df = pd.merge(three2023, one2023, how='left', on='Subjects')
# comp_df = pd.concat([three2023, one2023],axis=1)
# comp_df = comp_df.rename(columns={'Subj % 2023_x': 'Three Subjects % 2023', 'Subj % 2023_y': 'First Subjects % 2023', 'Subj % 2020_x': 'Three Subjects % 2020', 'Subj % 2020_y': 'First Subjects % 2020'})
#
#
# # Create double bar graph of both different subject headings
#
# comp_df = comp_df.head(15)
# comp_df
# #comp_df.plot(x='Subjects', y=['Three Subjects % 2023', 'First Subjects % 2023'], kind='barh')

# %%
#comp_df.plot(x='Subjects', y=['Three Subjects % 2023', 'First Subjects % 2023'], kind='barh')

# %% [markdown]
# three2023 = diff_three_df2023
# three2023 = three2023[['Subjects', 'Subj % 2023']]
# three2023 = three2023.rename(columns={'Subj % 2023': 'Three Subjects % 2023'})
# three2023 = three2023.sort_values('Three Subjects % 2023', ascending=False).reset_index(drop=True)
#
#
#
#
# one2023 = diff_one_df2023
# one2023 = one2023[['Subjects', 'Subj % 2023']]
# one2023 = one2023.rename(columns={'Subjects': 'One Subjects', 'Subj % 2023': 'One Subjects % 2023'})
# one2023 = one2023.sort_values('One Subjects % 2023', ascending=False).reset_index(drop=True)
#
#
#
#
# #comp_df = pd.merge(three2023, one2023, how='left', on='Subjects')
# comp_df = pd.concat([three2023, one2023], axis=1)
# comp_df = comp_df.head(15)
# comp_df

# %%
three2023 = diff_three_df2023 
three2023 = three2023[['Subjects', 'Subj % 2023']]
three2023 = three2023.rename(columns={'Subj % 2023': 'Three Subjects % 2023'})
#three2023 = three2023.sort_values('Three Subjects % 2023', ascending=False).reset_index(drop=True)




one2023 = diff_one_df2023 
one2023 = one2023[['Subjects', 'Subj % 2023']]
one2023 = one2023.rename(columns={'Subj % 2023': 'One Subjects % 2023'})
#one2023 = one2023.sort_values('One Subjects % 2023', ascending=False).reset_index(drop=True)




comp_df = pd.merge(three2023, one2023, how='left', on='Subjects')
#comp_df = pd.concat([three2023, one2023], axis=1)
comp_df['diff'] = abs(comp_df['One Subjects % 2023'] - comp_df['Three Subjects % 2023'])
comp_df = comp_df.sort_values('diff', ascending=False)
comp_df = comp_df.head(15).reset_index(drop=True)
comp_df
# Out:
#                                              Subjects  Three Subjects % 2023  \
# 0                   Architecture--Spain--Periodicals.               0.015130
# 1                           Architecture--Periodicals               0.020278
# 2                  Architecture, Modern--20th century               0.013882
# 3           Architecture, Domestic--Designs and plans               0.005147
# 4                  Architecture, Modern--21st century               0.007019
# 5                                        Architecture               0.010607
# 6                                    Building, Wooden               0.002808
# 7   Architecture, Modern--20th century--Designs an...               0.005459
# 8                 Architecture--Environmental aspects               0.006707
# 9   Architecture--United States--History--20th cen...               0.003120
# 10                                      City planning               0.005147
# ...

# %%
comp_df.sort_values('diff', ascending=True).plot(x='Subjects', y=['diff', 'One Subjects % 2023', 'Three Subjects % 2023'], kind='barh')
# Out:
# <Axes: ylabel='Subjects'>

# %%
comp_df.plot(x='Subjects', y=['Three Subjects % 2023', 'One Subjects % 2023'], kind='barh')
# Out:
# <Axes: ylabel='Subjects'>

# %%
three2023 = three2023.head(15)
three2023.plot(x='Subjects', y=['Three Subjects % 2023'], kind='barh')
# Out:
# <Axes: ylabel='Subjects'>

# %%
one2023 = one2023.head(15)
one2023.plot(x='Subjects', y=['One Subjects % 2023'], kind='barh')
# Out:
# <Axes: ylabel='Subjects'>

# %%
three2023
# Out:
#                                              Subjects  Three Subjects % 2023
# 0   Architecture--Espagne--20e siècle--Périodiques.               0.015130
# 1                   Architecture--Spain--Periodicals.               0.015130
# 2           Architecture, Domestic--Designs and plans               0.005147
# 3                            Architecture domestique.               0.003276
# 4   Architecture, Modern--20th century--Designs an...               0.005459
# 5                 Architecture--Environmental aspects               0.006707
# 6          Architecture--Japan--History--20th century               0.005147
# 7                         Architecture--Human factors               0.005771
# 8                            Sustainable architecture               0.005615
# 9                                        Architecture               0.010607
# 10                             Architecture, Domestic               0.004835
# ...

# %%
three_df
# Out:
#               Item Loan Id  Date In House Loan Indicator          Barcode  \
# 0      2252958767220001701  2018                       N  31951D01848189P
# 1      2252958767220001701  2018                       N  31951D01848189P
# 2      2252958767220001701  2018                       N  31951D01848189P
# 3      2252959196040001701  2018                       N  31951000140967E
# 4      2252959196040001701  2018                       N  31951000140967E
# ...                    ...   ...                     ...              ...
# 50971  2292994881510001701  2023                       N  31951D01782434F
# 50972  2292994881510001701  2023                       N  31951D01782434F
# 50973  2293026158410001701  2023                       N  31951D04275550F
# 50974  2293026158410001701  2023                       N  31951D04275550F
# 50975  2293026158410001701  2023                       N  31951D04275550F
#
#                      Call Number Circulation Library Code Owning Library Code  \
# ...

# %%
three2023 = diff_three_df2023 
three2023 = three2023[['Subjects', 'Subj % 2023']]
three2023 = three2023.rename(columns={'Subj % 2023': 'Three Subjects % 2023'})
three2023
# Out:
#                                                Subjects  Three Subjects % 2023
# 0     Architecture--Espagne--20e siècle--Périodiques.               0.015130
# 1                     Architecture--Spain--Periodicals.               0.015130
# 2             Architecture, Domestic--Designs and plans               0.005147
# 3                              Architecture domestique.               0.003276
# 4     Architecture, Modern--20th century--Designs an...               0.005459
# ...                                                 ...                    ...
# 6451  Disasters--Social aspects--New York (State)--N...                    NaN
# 6452                                          Disasters                    NaN
# 6453  Disaster victims--Dwellings--Design and constr...                    NaN
# 6454                                    Disaster relief                    NaN
# 6455  p--z--y--Architecture (object genre)--Japan--2...                    NaN
#
# [6456 rows x 2 columns]

# %%
comp_df
# Out:
#                                              Subjects  Three Subjects % 2023  \
# 0                   Architecture--Spain--Periodicals.               0.015130
# 1                           Architecture--Periodicals               0.020278
# 2                  Architecture, Modern--20th century               0.013882
# 3           Architecture, Domestic--Designs and plans               0.005147
# 4                  Architecture, Modern--21st century               0.007019
# 5                                        Architecture               0.010607
# 6                                    Building, Wooden               0.002808
# 7   Architecture, Modern--20th century--Designs an...               0.005459
# 8                 Architecture--Environmental aspects               0.006707
# 9   Architecture--United States--History--20th cen...               0.003120
# 10                                      City planning               0.005147
# ...

# %%
ax = comp_df.plot(x="Subjects", y='Three Subjects % 2023', kind="barh", rot=0) 
comp_df.plot(x="Subjects", y='One Subjects % 2023', kind="barh", ax=ax, rot=0, color="maroon")
# Out:
# <Axes: ylabel='Subjects'>

# %%
comp_df.plot(x="Subjects", y=['Three Subjects % 2023', 'One Subjects % 2023'], kind="barh")
# Out:
# <Axes: ylabel='Subjects'>

# %%
three2020 = diff_three_df2023 
three2020 = three2020[['Subjects', 'Subj % 2020']]
three2020 = three2020.rename(columns={'Subj % 2020': 'Three Subjects % 2020'})
three2020 = three2020.sort_values('Three Subjects % 2020', ascending=False).reset_index(drop=True)




one2020 = diff_one_df2023
one2020 = one2020[['Subjects', 'Subj % 2020']]
one2020 = one2020.rename(columns={'Subjects': 'One Subjects', 'Subj % 2020': 'One Subjects % 2020'})
one2020 = one2020.sort_values('One Subjects % 2020', ascending=False).reset_index(drop=True)




#comp_df = pd.merge(three2023, one2023, how='left', on='Subjects')
comp_df2020 = pd.concat([three2020, one2020], axis=1)
comp_df2020 = comp_df2020.head(15)
comp_df2020
# Out:
#                                              Subjects  Three Subjects % 2020  \
# 0                  Architecture, Modern--20th century               0.016149
# 1                                       City planning               0.011506
# 2                 Architecture--Environmental aspects               0.008074
# 3                           Architecture--Periodicals               0.007872
# 4                  Architecture, Modern--21st century               0.007065
# 5                                Architectural design               0.006056
# 6                            Architecture and society               0.006056
# 7                         Architecture--Human factors               0.006056
# 8                            Sustainable architecture               0.005854
# 9                                        Architecture               0.005450
# 10                  Architecture--Spain--Periodicals.               0.005046
# ...

# %%
ax = comp_df2020.plot(x="Subjects", y='Three Subjects % 2020', kind="barh") 
comp_df2020.plot(x="One Subjects", y='One Subjects % 2020', kind="barh", ax=ax, color="maroon")
# Out:
# <Axes: ylabel='One Subjects'>

# %%
three2023 = diff_three_df2023 
three2023 = three2023[['Subjects', '2023 Diff 2018']]
#three2023 = three2023.rename(columns={'Subj % 2023': 'Three Subjects % 2023', 'Subj % 2020': 'Three Subjects % 2020'})
three2023 = three2023.sort_values('2023 Diff 2018', ascending=False)
three2023.head(15)
# Out:
#                                              Subjects  2023 Diff 2018
# 0   Architecture--Espagne--20e siècle--Périodiques.        0.007629
# 1                   Architecture--Spain--Periodicals.        0.007559
# 2           Architecture, Domestic--Designs and plans        0.003272
# 3                            Architecture domestique.        0.003067
# 4   Architecture, Modern--20th century--Designs an...        0.002959
# 5                 Architecture--Environmental aspects        0.002540
# 6          Architecture--Japan--History--20th century        0.002300
# 7                         Architecture--Human factors        0.002229
# 8                            Sustainable architecture        0.001865
# 9                                        Architecture        0.001785
# 10                             Architecture, Domestic        0.001779
# 11                             Landscape architecture        0.001621
# ...

# %%
one2023.head(15)
# Out:
#                                        Subjects  One Subjects % 2023
# 0             Architecture--Spain--Periodicals.             0.037641
# 1     Architecture, Domestic--Designs and plans             0.010477
# 2           Architecture--Environmental aspects             0.009701
# 3                        Landscape architecture             0.007761
# 4                              Building, Wooden             0.006209
# 5                           Architecture--Japan             0.003492
# 6                      Architecture and climate             0.004269
# 7                        Architecture, Domestic             0.005045
# 8    Architecture--Japan--History--20th century             0.003880
# 9                         Light in architecture             0.003880
# 10  Architecture, Domestic--Spain--Periodicals.             0.002328
# 11                                      Facades             0.002716
# 12            Alexander--VII,--Pope,--1599-1667             0.002328
# ...

# %%
diff_three_df2023
# Out:
#                                                Subjects  Subj % 2018  \
# 0     Architecture--Espagne--20e siècle--Périodiques.     0.007502
# 1                     Architecture--Spain--Periodicals.     0.007571
# 2             Architecture, Domestic--Designs and plans     0.001875
# 3                              Architecture domestique.     0.000208
# 4     Architecture, Modern--20th century--Designs an...     0.002501
# ...                                                 ...          ...
# 6451  Disasters--Social aspects--New York (State)--N...     0.000069
# 6452                                          Disasters     0.000069
# 6453  Disaster victims--Dwellings--Design and constr...     0.000069
# 6454                                    Disaster relief     0.000069
# 6455  p--z--y--Architecture (object genre)--Japan--2...     0.000069
#
#       Subj % 2019  Subj % 2020  Subj % 2021  Subj % 2022  Subj % 2023  \
# ...

# %%
# Create DataFrames from Series
#df1 = pd.DataFrame(three_subject_counts).reset_index()
#df2 = pd.DataFrame(one_subject_counts).reset_index()

# Merge SeriDataFrames into one DataFrame
bar_df = pd.merge(df1, df2, how='left', on='Subjects')
bar_df = bar_df.rename(columns={'count_x': 'Three Subjects', 'count_y': 'First Subjects'})
bar_df.head(25)

bar_df = bar_df.head(30)
bar_df.plot(x='Subjects', y=['First Subjects', 'Three Subjects'], kind='barh')
# Out:
# <Axes: ylabel='Subjects'>

# %%
one2023.head(15)
# Out:
#                                        Subjects  One Subjects % 2023
# 0             Architecture--Spain--Periodicals.             0.037641
# 1     Architecture, Domestic--Designs and plans             0.010477
# 2           Architecture--Environmental aspects             0.009701
# 3                        Landscape architecture             0.007761
# 4                              Building, Wooden             0.006209
# 5                           Architecture--Japan             0.003492
# 6                      Architecture and climate             0.004269
# 7                        Architecture, Domestic             0.005045
# 8    Architecture--Japan--History--20th century             0.003880
# 9                         Light in architecture             0.003880
# 10  Architecture, Domestic--Spain--Periodicals.             0.002328
# 11                                      Facades             0.002716
# 12            Alexander--VII,--Pope,--1599-1667             0.002328
# ...

# %%
three2023.head(15)
# Out:
#                                              Subjects  2023 Diff 2018
# 0   Architecture--Espagne--20e siècle--Périodiques.        0.007629
# 1                   Architecture--Spain--Periodicals.        0.007559
# 2           Architecture, Domestic--Designs and plans        0.003272
# 3                            Architecture domestique.        0.003067
# 4   Architecture, Modern--20th century--Designs an...        0.002959
# 5                 Architecture--Environmental aspects        0.002540
# 6          Architecture--Japan--History--20th century        0.002300
# 7                         Architecture--Human factors        0.002229
# 8                            Sustainable architecture        0.001865
# 9                                        Architecture        0.001785
# 10                             Architecture, Domestic        0.001779
# 11                             Landscape architecture        0.001621
# ...

# %%
comp_df
# Out:
#                                              Subjects  Three Subjects % 2023  \
# 0                   Architecture--Spain--Periodicals.               0.015130
# 1                           Architecture--Periodicals               0.020278
# 2                  Architecture, Modern--20th century               0.013882
# 3           Architecture, Domestic--Designs and plans               0.005147
# 4                  Architecture, Modern--21st century               0.007019
# 5                                        Architecture               0.010607
# 6                                    Building, Wooden               0.002808
# 7   Architecture, Modern--20th century--Designs an...               0.005459
# 8                 Architecture--Environmental aspects               0.006707
# 9   Architecture--United States--History--20th cen...               0.003120
# 10                                      City planning               0.005147
# ...

# %%
three_2023 = diff_three_df2023.head(15).sort_values('2023 Diff 2018', ascending=True).plot(x="Subjects", y=['Subj % 2023'], kind="barh") 
one_2023 = diff_one_df2023.head(15).sort_values('2023 Diff 2018', ascending=True).plot(x="Subjects", y=['Subj % 2023'], kind="barh") 

#three_plot2023_2.set_title('Three Subject Heading Sorted By Largest 2023 Diff 2018')

#three_plot2023_2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 6
#       2 one_2023 = diff_one_df2023.head(15).sort_values('2023 Diff 2018', ascending=True).plot(x="Subjects", y=['Subj % 2023'], kind="barh")
#       4 #three_plot2023_2.set_title('Three Subject Heading Sorted By Largest 2023 Diff 2018')
# ----> 6 three_plot2023_2
#
# NameError: name 'three_plot2023_2' is not defined

# %%
# create a table of call number by subjects and date for one subject headings
CallNumberCounts = one_df.groupby(['Call Number', 'Subjects', 'Date']).size().reset_index(name='Counts').sort_values(by=['Counts'], ascending=[False])
CallNumberCounts.reset_index(drop = True).head(25)
# Out:
#                  Call Number  \
# 0                    Unknown
# 1                    Unknown
# 2                    Unknown
# 3                    Unknown
# 4                    Unknown
# 5                    Unknown
# 6                    Unknown
# 7                    Unknown
# 8                    Unknown
# 9                    Unknown
# 10                   Unknown
# 11         NA1559.A5 A4 2005
# 12        Quarto NA7126 .G13
# 13          SB470.O5 A2 1977
# 14        Quarto NA7126 .G13
# 15         Folio NA680 .G57x
# 16  Quarto NA2500 .L384 2004
# 17           NA687 .K66 2014
# 18         NA1559.A5 A4 2005
# 19      NA1046.5.N4 E84 1994
# 20                   Unknown
# 21         NA1559.A5 A4 2005
# 22         Folio NA680 .G57x
# 23         N6415.B3 M37 1977
# 24                   Unknown
#
#                                              Subjects  Date  Counts
# 0                           Architecture--Periodicals  2019     172
# ...

# %%
# remove unknown call numbers
CallNumberCounts = CallNumberCounts[(CallNumberCounts['Call Number'] != 'Unknown')]
CallNumberCounts = CallNumberCounts.head(25).reset_index(drop=True)

# %%
CallNumberCounts.head(25)
# Out:
#                  Call Number  \
# 0          NA1559.A5 A4 2005
# 1         Quarto NA7126 .G13
# 2           SB470.O5 A2 1977
# 3         Quarto NA7126 .G13
# 4          Folio NA680 .G57x
# 5   Quarto NA2500 .L384 2004
# 6            NA687 .K66 2014
# 7          NA1559.A5 A4 2005
# 8       NA1046.5.N4 E84 1994
# 9          NA1559.A5 A4 2005
# 10         Folio NA680 .G57x
# 11         N6415.B3 M37 1977
# 12       NA6750.P4 E956 2000
# 13           NA510 .A64 2013
# 14               TA663 .I15x
# 15        Quarto NA208 .P47x
# 16        NA9183 .B7213 1988
# 17    Quarto NA642 .F72 1995
# 18        Quarto NA1046 .B75
# 19        Quarto NA7126 .G13
# 20  Quarto SB470.O5 B48 2008
# 21         NA1559.A5 A4 2005
# 22  Quarto SB470.O5 H34 1995
# 23              NA737.B68 A7
# 24            NA520 .W5 1988
#
#                                              Subjects  Date  Counts
# 0                                 Andō, Tadao,--1941-  2021      22
# ...

# %%
# create a table of call number by subjects and date for three subject headings
ThreeCallNumberCounts = three_df.groupby(['Call Number', 'Subjects', 'Date']).size().reset_index(name='Counts').sort_values(by=['Counts'], ascending=[False])
ThreeCallNumberCounts.reset_index(drop = True).head(25)
# Out:
#    Call Number                                           Subjects  Date  \
# 0      Unknown                          Architecture--Periodicals  2019
# 1      Unknown                          Architecture--Periodicals  2018
# 2      Unknown                          Architecture--Periodicals  2022
# 3      Unknown                  Architecture--Spain--Periodicals.  2019
# 4      Unknown  Architecture--Espagne--20e siècle--Périodiques.  2019
# 5      Unknown                  Architecture--Spain--Periodicals.  2022
# 6      Unknown                          Architecture--Periodicals  2023
# 7      Unknown  Architecture--Espagne--20e siècle--Périodiques.  2022
# 8      Unknown                  Architecture--Spain--Periodicals.  2018
# 9      Unknown  Architecture--Espagne--20e siècle--Périodiques.  2018
# 10     Unknown  Architecture--Espagne--20e siècle--Périodiques.  2023
# 11     Unknown                  Architecture--Spain--Periodicals.  2023
# ...

# %%
# remove unknown call numbers
ThreeCallNumberCounts = ThreeCallNumberCounts[(ThreeCallNumberCounts['Call Number'] != 'Unknown')]
ThreeCallNumberCounts = ThreeCallNumberCounts.head(25).reset_index(drop=True)

# %%
ThreeCallNumberCounts.head(25)
# Out:
#                  Call Number  \
# 0          NA1559.A5 A4 2005
# 1          NA1559.A5 A4 2005
# 2          NA1559.A5 A4 2005
# 3         Quarto NA7126 .G13
# 4         Quarto NA7126 .G13
# 5         Quarto NA7126 .G13
# 6           SB470.O5 A2 1977
# 7           SB470.O5 A2 1977
# 8           SB470.O5 A2 1977
# 9         Quarto NA7126 .G13
# 10        Quarto NA7126 .G13
# 11        Quarto NA7126 .G13
# 12           NA687 .K66 2014
# 13  Quarto NA2500 .L384 2004
# 14           NA687 .K66 2014
# 15  Quarto NA2500 .L384 2004
# 16         Folio NA680 .G57x
# 17           NA687 .K66 2014
# 18         NA1559.A5 A4 2005
# 19         NA1559.A5 A4 2005
# 20         NA1559.A5 A4 2005
# 21      NA1046.5.N4 E84 1994
# 22      NA1046.5.N4 E84 1994
# 23      NA1046.5.N4 E84 1994
# 24         N6415.B3 M37 1977
#
#                                              Subjects  Date  Counts
# 0                           Inscriptions (Provenance)  2021      22
# ...

# %%
# Table comparing most popular title and subjects for three subject dataset

TitleCountsThree= three_df.groupby(['Title', 'Subjects']).size().reset_index(name='Counts').sort_values(by=['Counts'], ascending=[False])
TitleCountsThree.reset_index(drop = True).head(25)
# Out:
#                                                 Title  \
# 0                                         El Croquis.
# 1                                         El Croquis.
# 2                                         El Croquis.
# 3                                             Detail.
# 4                                             Detail.
# 5                                             Detail.
# 6   Kenchiku to toshi = Architecture and urbanism ...
# 7   Kenchiku to toshi = Architecture and urbanism ...
# 8   Kenchiku to toshi = Architecture and urbanism ...
# 9   Tadao ando : the process of creation: emaki-st...
# 10  Tadao ando : the process of creation: emaki-st...
# 11  Tadao ando : the process of creation: emaki-st...
# 12                                         GA houses.
# 13                                         GA houses.
# 14                                         GA houses.
# 15  Global architecture book / edited and photogra...
# ...

# %%
# Table comparing most popular title, Date, and subjects for three subject dataset

TitleCountsThree= three_df.groupby(['Title', 'Subjects', 'Date']).size().reset_index(name='Counts').sort_values(by=['Counts'], ascending=[False])
TitleCountsThree.reset_index(drop = True).head(25)
# Out:
#                                                 Title  \
# 0                                         El Croquis.
# 1                                         El Croquis.
# 2                                         El Croquis.
# 3                                         El Croquis.
# 4                                         El Croquis.
# 5                                         El Croquis.
# 6                                         El Croquis.
# 7                                         El Croquis.
# 8                                         El Croquis.
# 9                                         El Croquis.
# 10                                        El Croquis.
# 11                                        El Croquis.
# 12                                            Detail.
# 13                                            Detail.
# 14                                            Detail.
# 15                                        El Croquis.
# ...

# %%
# Table comparing most popular title and subjects for one subject dataset
TitleCountsOne= one_df.groupby(['Title', 'Subjects']).size().reset_index(name='Counts').sort_values(by=['Counts'], ascending=[False])
TitleCountsOne.reset_index(drop = True).head(25)
# Out:
#                                                 Title  \
# 0                                         El Croquis.
# 1                                             Detail.
# 2   Kenchiku to toshi = Architecture and urbanism ...
# 3   Tadao ando : the process of creation: emaki-st...
# 4                                          GA houses.
# 5   Global architecture book / edited and photogra...
# 6                               Architectural record.
# 7                                The Japan architect.
# 8   2G : revista internacional de arquitectura = i...
# 9   Elements / Rem Koolhaas ; editor in chief, Jam...
# 10               The papers of Frederick Law Olmsted.
# 11  Beatrix : the gardening life of Beatrix Jones ...
# 12  The master list of design projects of the Olms...
# 13                            Architectural diagrams.
# 14                        Architectural design : A.D.
# 15  Learning from Las Vegas : the forgotten symbol...
# ...

# %%
# Table comparing most popular title, date, and subjects for one subject dataset
TitleCountsOne= one_df.groupby(['Title', 'Subjects', 'Date']).size().reset_index(name='Counts').sort_values(by=['Counts'], ascending=[False])
TitleCountsOne.reset_index(drop = True).head(25)
# Out:
#                                                 Title  \
# 0                                         El Croquis.
# 1                                         El Croquis.
# 2                                         El Croquis.
# 3                                         El Croquis.
# 4                                             Detail.
# 5                                         El Croquis.
# 6                                             Detail.
# 7                                             Detail.
# 8   Kenchiku to toshi = Architecture and urbanism ...
# 9                                         El Croquis.
# 10  Tadao ando : the process of creation: emaki-st...
# 11                                         GA houses.
# 12               The papers of Frederick Law Olmsted.
# 13                                         GA houses.
# 14                                            Detail.
# 15                              Architectural record.
# ...
